# %%
import pandas as pd

# %%
titanic = pd.read_csv('data/titanic_train.csv', index_col=False, squeeze=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pib = pd.read_excel('data/PIB dos Municipios - base de dados 2010-2016.xls', index_col=False, squeeze=True)
pib
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 0      2010                        1                 Norte
# 1      2010                        1                 Norte
# 2      2010                        1                 Norte
# 3      2010                        1                 Norte
# 4      2010                        1                 Norte
# ...     ...                      ...                   ...
# 24932  2014                        3               Sudeste
# 24933  2014                        3               Sudeste
# 24934  2014                        3               Sudeste
# 24935  2014                        3               Sudeste
# 24936  2014                        3               Sudeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                                  11                            RO
# 1                                  11                            RO
# ...

# %%
iris = pd.read_json('data/iris.json')
iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
champions = pd.read_json('data/champion_info.json')
champions
# Out:
#          type version                                               data
# 1    champion  7.17.2  {'title': 'the Dark Child', 'id': 1, 'key': 'A...
# 10   champion  7.17.2  {'title': 'The Judicator', 'id': 10, 'key': 'K...
# 101  champion  7.17.2  {'title': 'the Magus Ascendant', 'id': 101, 'k...
# 102  champion  7.17.2  {'title': 'the Half-Dragon', 'id': 102, 'key':...
# 103  champion  7.17.2  {'title': 'the Nine-Tailed Fox', 'id': 103, 'k...
# ..        ...     ...                                                ...
# 91   champion  7.17.2  {'title': 'the Blade's Shadow', 'id': 91, 'key...
# 92   champion  7.17.2  {'title': 'the Exile', 'id': 92, 'key': 'Riven...
# 96   champion  7.17.2  {'title': 'the Mouth of the Abyss', 'id': 96, ...
# 98   champion  7.17.2  {'title': 'the Eye of Twilight', 'id': 98, 'ke...
# 99   champion  7.17.2  {'title': 'the Lady of Luminosity', 'id': 99, ...
#
# [138 rows x 3 columns]

# %%
tracking = pd.read_parquet('data/user_tracking.parquet', engine='pyarrow')
tracking
# Out:
#       installation_number external_identifier                   handset  \
# 0                 7206043                              samsung:SM-J700M
# 1                 6219664           367738313      LENOVO:Lenovo K33b36
# 2                 6485586                              samsung:SM-G928G
# 3                 7050958           108659666          samsung:SM-G930F
# 4                 7131516           108027625           asus:ASUS_X013D
# ...                   ...                 ...                       ...
# 28291             7210849                      motorola:Moto G (5) Plus
# 28292             6660693           441385055     motorola:Moto Z2 Play
# 28293             6848495           506809026          samsung:SM-J700M
# 28294             7110078                          motorola:Moto G (5S)
# 28295             6272408           475939424          samsung:SM-G610F
#
#             os os_version         host_app_package host_app_version  \
# ...

# %%
import sqlite3

cnx = sqlite3.connect('dataread.db')

sql = open("data/cliente_cidade.sql", "r")
sql_string = sql.read()

data = cnx.executescript(sql_string)

df = pd.read_sql(sql='SELECT * FROM Cliente;', con=cnx) 
df
# Out:
#      idCliente                                         nome  codIBGE
# 0            7              Prefeitura Municipal de Aimorés  3101102
# 1           16             Prefeitura Municipal de Argirita  3104403
# 2           20             Prefeitura Municipal de Bandeira  3105202
# 3           21      Prefeitura Municipal de Barão de Cocais  3105400
# 4           22  Prefeitura Municipal de Bela Vista de Minas  3106002
# ..         ...                                          ...      ...
# 162        431                Prefeitura Municipal de Palma  3146701
# 163        432         Prefeitura de Santa Maria de Itabira  3158003
# 164        435                Câmara Municipal de Tarumirim     None
# 165        436       Câmara Municipal de Fernandes Tourinho     None
# 166        437              Câmara Municipal de Sabinópolis     None
#
# [167 rows x 3 columns]
